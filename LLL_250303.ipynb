# %%
import numpy as np

def GSO(B): #グラム・シュミット直交化
  n = len(B)
  B_star = np.zeros_like(B, dtype=float)
  mu = np.eye(n)

  for i in range(n):
      B_star[i] = B[i]
      for j in range(i):
        mu[i, j] = np.dot(B[i], B_star[j]) / np.dot(B_star[j], B_star[j])
        B_star[i] -= mu[i, j] * B_star[j]

  return B_star, mu

#(i,j)成分に関する部分サイズ簡約
def Partial_Size_Reduce(B, mu, i, j):
  if abs(mu[i,j]) > 0.5:
    q = round(mu[i, j])
    #|mu[i,j]| <= 0.5 となるようにB[i]を取り直す
    B[i] -= q * B[j]
    #GSO係数の更新
    for l in range(j+1):
      mu[i,l] -= q * mu[j,l]

#Lovasz条件(True or Falseを出力)
def lovasz_condition(B_star_norm, mu, delta, i):
  return B_star_norm[i] >= (delta - mu[i, i-1]**2) *B_star_norm[i-1]

#効率的なGSO情報更新
def GSOUpdate_LLL(B_star_norm, mu, k) :
  #更新されると困る繰り返し用いる値を固定
  nu = mu[k,k-1]
  B_temp = B_star_norm[k] + nu**2 * B_star_norm[k-1]
  #(i,j)=(k,k-1)に関する値を更新
  mu[k,k-1] = nu * B_star_norm[k-1] / B_temp
  B_star_norm[k] = B_star_norm[k] * B_star_norm[k-1] / B_temp
  B_star_norm[k-1] = B_temp
  #(i,j)=(k,j),(k-1,j)に関する値を更新
  for j in range(0,k-1):
    mu[k-1,j], mu[k,j] = mu[k,j], mu[k-1,j]
  #(i,j)=(i,k), (i,k-1)に関する値を更新
  for i in range(k+1, len(B_star_norm)):
    t = mu[i,k]
    mu[i,k] = mu[i,k-1] - nu * t
    mu[i,k-1] = t + mu[k,k-1] * mu[i,k]

  return B_star_norm, mu

#LLL基底簡約アルゴリズム
def LLL(B, delta=0.75):
  n = len(B)
  #Bの型をnp.arrayに
  B = np.array(B, dtype=int)
  #BのGSO情報を取得
  B_star, mu = GSO(B)
  #B_starの2乗ノルムを格納する配列を作成（初期値として0）
  B_star_norm = np.zeros(n)
  #B_star_binormにBの情報を入れる
  for i in range(n):
    B_star_norm[i] = np.linalg.norm(B_star[i])**2

  #行の初期値（mu[0,0]=1なので次の行からスタート）
  k = 1
  while k < n:
    #(k,j)成分に関して部分サイズ簡約
    for j in range(k-1, -1, -1):
      Partial_Size_Reduce(B, mu, k, j)

    #kにおけるLovasz条件の判定
    if lovasz_condition(B_star_norm, mu, delta, k):
      #もしOKならkを更新
      k += 1
    else:
      #もしFalseなら隣り合う基底ベクトルを交換
      B[[k-1,k]] = B[[k,k-1]]
      #↑素朴な方法（temp使う or a , b = b , a みたいな感じ）だと上手くいかなかったのでchatGPTに聞いた
      #GSO情報を更新
      B_star_norm, mu = GSOUpdate_LLL(B_star_norm, mu, k)
      #kの値を更新
      k = max(k-1, 1)

  return B

#LLL基底簡約アルゴリズムの挙動確認版
def test_LLL(B, delta=0.75):
  n = len(B)
  #Bの型をndarrayに
  B = np.array(B, dtype=int)
  #BのGSO情報を取得
  B_star, mu = GSO(B)
  #B_starの2乗ノルムを格納する配列を作成（初期値として0）
  B_star_norm = np.zeros(n)
  #B_star_binormにBの情報を入れる
  for i in range(n):
    B_star_norm[i] = np.linalg.norm(B_star[i])**2
  #GSOベクトル行列, GSO係数行列, GSOベクトルの二乗ノルムを表示
  print('---')
  print('Initial condition :')
  print('GSO_vectors')
  print(B_star)
  print('GSO_coefficients')
  print(mu)
  print('GSO_vector_norm')
  print(B_star_norm)

  #行の初期値（mu[0,0]=1なので次の行からスタート）
  k = 1

  while k < n:
    print('---')
    print('k =',k)
    #(k,j)成分に関して部分サイズ簡約
    for j in range(k-1, -1, -1):
      Partial_Size_Reduce(B, mu, k, j)

      #基底簡約後の基底行列, GSO係数行列, GSOベクトルのノルムを表示
      print('---')
      print('Partial_Size_Reduction')
      print('(k,j) : ')
      print(k,j)
      print('Basis matrix : B')
      print(B)
      print('GSO coefficients : mu')
      print(mu)
      print('GSO vector norm : B_star_norm')
      print(B_star_norm)

    #Lovasz条件の表示
    print('---')
    print('Lovasz condition at k =',k,':',lovasz_condition(B_star_norm, mu, delta, k))

    #kにおけるLovasz条件の判定
    if lovasz_condition(B_star_norm, mu, delta, k):
      #もしOKならkを更新
      k += 1
      print('k += 1')

    else:
      #もしFalseなら隣り合う基底ベクトルを交換
      print('---')
      print(B)
      B[[k-1,k]] = B[[k,k-1]]
      #↑素朴な方法（temp使う or a , b = b , a みたいな感じ）だと上手くいかなかったのでchatGPTに聞いた
      print('---')
      print('swap(B[k-1], B[k])')
      print('---')
      print(B)
      #GSO情報を更新
      B_star_norm, mu = GSOUpdate_LLL(B_star_norm, mu, k)
      print('---')
      print('update GSO info')
      print('GSO coefficients : mu')
      print(mu)
      print('GSO vector norm : B_star_norm')
      print(B_star_norm)

      #kの値を更新
      k = max(k-1, 1)
      print('---')
      print('update k = max(k-1,1) =',k)

  return B

# %%
# 標準入力から行列を生成
def input_basis_form():
  print("Enter the dimension of the lattice.")
  print("Enter each basis vector of the lattice")
  n = int(input())
  B = np.array([list(map(int,input().split())) for _ in range(n)])
  return B

# 標準入力でLLLに入れる行列を入力する
def test_LLL_with_stdin():
  B = input_basis_form()
  print("Enter the value of delta")
  delta = float(input())
  test_LLL(B, delta)

# ランダムな整数係数フルランク行列を生成するアルゴリズム（やっつけバージョン）
def create_randint_fullrank_matrix():
  print("Enter the size of matrix")
  s = list(map(int, input().split()))
  row = s[0]
  col = s[1]
  while True:
    rand = np.random.randint(-1000, 1000, size=(row, col))
    if np.linalg.matrix_rank(rand) == row:
      return rand
    else:
      continue

# ランダムな整数係数フルランク行列にLLLを適用する
def test_LLL_with_random_matrix():
  B = create_randint_fullrank_matrix()
  print("The basis matrix is")
  print(B)
  print("---")
  print("Enter the value of delta")
  delta = float(input())
  print("---")
  print("Do you want to check each step?[y/n]")
  answer = input()
  if answer == "y":
    print(test_LLL(B, delta))
  else:
    print("the LLL reduced basis is")
    print(LLL(B, delta))

# %%
B1 = np.array([
     [9, 2, 7],
    [8, 6, 1],
    [3, 2, 6],
])
print("Original Basis:")
print(B1)

B1_LLL = LLL(B1, delta=0.99)
print("LLL-reduced Basis:")
print(B1_LLL)
# Out:
# Original Basis:
# [[9 2 7]
#  [8 6 1]
#  [3 2 6]]
# LLL-reduced Basis:
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]

# %%
#You can also check the behavior at each step of LLL
print(test_LLL(B1, delta=0.99))
# Out:
# ---
# Initial condition :
# GSO_vectors
# [[ 9.          2.          7.        ]
#  [ 1.8880597   4.64179104 -3.75373134]
#  [-1.53816867  1.80734818  1.46126023]]
# GSO_coefficients
# [[ 1.          0.          0.        ]
#  [ 0.67910448  1.          0.        ]
#  [ 0.54477612 -0.19322292  1.        ]]
# GSO_vector_norm
# [134.          39.20149254   7.76775176]
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 9  2  7]
#  [-1  4 -6]
#  [ 3  2  6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [-0.32089552  1.          0.        ]
#  [ 0.54477612 -0.19322292  1.        ]]
# GSO vector norm : B_star_norm
# [134.          39.20149254   7.76775176]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[ 9  2  7]
#  [-1  4 -6]
#  [ 3  2  6]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-1  4 -6]
#  [ 9  2  7]
#  [ 3  2  6]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [-0.81132075  1.          0.        ]
#  [-0.58490566  0.48277175  1.        ]]
# GSO vector norm : B_star_norm
# [53.         99.11320755  7.76775176]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-1  4 -6]
#  [ 8  6  1]
#  [ 3  2  6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.18867925  1.          0.        ]
#  [-0.58490566  0.48277175  1.        ]]
# GSO vector norm : B_star_norm
# [53.         99.11320755  7.76775176]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[-1  4 -6]
#  [ 8  6  1]
#  [ 3  2  6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.18867925  1.          0.        ]
#  [-0.58490566  0.48277175  1.        ]]
# GSO vector norm : B_star_norm
# [53.         99.11320755  7.76775176]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[-1  4 -6]
#  [ 8  6  1]
#  [ 2  6  0]]
# GSO coefficients : mu
# [[1.         0.         0.        ]
#  [0.18867925 1.         0.        ]
#  [0.41509434 0.48277175 1.        ]]
# GSO vector norm : B_star_norm
# [53.         99.11320755  7.76775176]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[-1  4 -6]
#  [ 8  6  1]
#  [ 2  6  0]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-1  4 -6]
#  [ 2  6  0]
#  [ 8  6  1]]
# ---
# update GSO info
# GSO coefficients : mu
# [[1.         0.         0.        ]
#  [0.41509434 1.         0.        ]
#  [0.18867925 1.55012225 1.        ]]
# GSO vector norm : B_star_norm
# [53.         30.86792453 24.94132029]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-1  4 -6]
#  [ 2  6  0]
#  [ 8  6  1]]
# GSO coefficients : mu
# [[1.         0.         0.        ]
#  [0.41509434 1.         0.        ]
#  [0.18867925 1.55012225 1.        ]]
# GSO vector norm : B_star_norm
# [53.         30.86792453 24.94132029]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[-1  4 -6]
#  [ 2  6  0]
#  [ 8  6  1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 2  6  0]
#  [-1  4 -6]
#  [ 8  6  1]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.55        1.          0.        ]
#  [ 1.3        -0.45476773  1.        ]]
# GSO vector norm : B_star_norm
# [40.         40.9        24.94132029]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 2  6  0]
#  [-3 -2 -6]
#  [ 8  6  1]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [-0.45        1.          0.        ]
#  [ 1.3        -0.45476773  1.        ]]
# GSO vector norm : B_star_norm
# [40.         40.9        24.94132029]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 2  6  0]
#  [-3 -2 -6]
#  [ 8  6  1]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [-0.45        1.          0.        ]
#  [ 1.3        -0.45476773  1.        ]]
# GSO vector norm : B_star_norm
# [40.         40.9        24.94132029]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 2  6  0]
#  [-3 -2 -6]
#  [ 6  0  1]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [-0.45        1.          0.        ]
#  [ 0.3        -0.45476773  1.        ]]
# GSO vector norm : B_star_norm
# [40.         40.9        24.94132029]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[ 2  6  0]
#  [-3 -2 -6]
#  [ 6  0  1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 2  6  0]
#  [ 6  0  1]
#  [-3 -2 -6]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.3         1.          0.        ]
#  [-0.45       -0.55688623  1.        ]]
# GSO vector norm : B_star_norm
# [40.         33.4        30.54191617]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 2  6  0]
#  [ 6  0  1]
#  [-3 -2 -6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.3         1.          0.        ]
#  [-0.45       -0.55688623  1.        ]]
# GSO vector norm : B_star_norm
# [40.         33.4        30.54191617]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[ 2  6  0]
#  [ 6  0  1]
#  [-3 -2 -6]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 6  0  1]
#  [ 2  6  0]
#  [-3 -2 -6]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.32432432  1.          0.        ]
#  [-0.64864865 -0.28293413  1.        ]]
# GSO vector norm : B_star_norm
# [37.         36.10810811 30.54191617]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 6  0  1]
#  [ 2  6  0]
#  [-3 -2 -6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.32432432  1.          0.        ]
#  [-0.64864865 -0.28293413  1.        ]]
# GSO vector norm : B_star_norm
# [37.         36.10810811 30.54191617]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 6  0  1]
#  [ 2  6  0]
#  [-3 -2 -6]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.32432432  1.          0.        ]
#  [-0.64864865 -0.28293413  1.        ]]
# GSO vector norm : B_star_norm
# [37.         36.10810811 30.54191617]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 6  0  1]
#  [ 2  6  0]
#  [ 3 -2 -5]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.32432432  1.          0.        ]
#  [ 0.35135135 -0.28293413  1.        ]]
# GSO vector norm : B_star_norm
# [37.         36.10810811 30.54191617]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[ 6  0  1]
#  [ 2  6  0]
#  [ 3 -2 -5]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.35135135  1.          0.        ]
#  [ 0.32432432 -0.30557801  1.        ]]
# GSO vector norm : B_star_norm
# [37.         33.43243243 32.98625707]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.35135135  1.          0.        ]
#  [ 0.32432432 -0.30557801  1.        ]]
# GSO vector norm : B_star_norm
# [37.         33.43243243 32.98625707]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.35135135  1.          0.        ]
#  [ 0.32432432 -0.30557801  1.        ]]
# GSO vector norm : B_star_norm
# [37.         33.43243243 32.98625707]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]
# GSO coefficients : mu
# [[ 1.          0.          0.        ]
#  [ 0.35135135  1.          0.        ]
#  [ 0.32432432 -0.30557801  1.        ]]
# GSO vector norm : B_star_norm
# [37.         33.43243243 32.98625707]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# [[ 6  0  1]
#  [ 3 -2 -5]
#  [ 2  6  0]]

# %%
B2 = np.array([
  [-2, 7, 7, -5],
  [3, -2, 6, -1],
  [2, -8, -9, -7],
  [8, -9, 6, -4],
])
print("Original Basis:")
print(B2)

B2_LLL = LLL(B2, delta=0.75)
print("LLL-reduced Basis:")
print(B2_LLL)
# Out:
# Original Basis:
# [[-2  7  7 -5]
#  [ 3 -2  6 -1]
#  [ 2 -8 -9 -7]
#  [ 8 -9  6 -4]]
# LLL-reduced Basis:
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]

# %%
print(test_LLL(B2, delta=0.75))
# Out:
# ---
# Initial condition :
# GSO_vectors
# [[-2.00000000e+00  7.00000000e+00  7.00000000e+00 -5.00000000e+00]
#  [ 3.42519685e+00 -3.48818898e+00  4.51181102e+00  6.29921260e-02]
#  [ 1.10104964e+00 -3.64543676e+00 -3.50827255e+00 -1.04556129e+01]
#  [ 6.02114788e-01  3.55156871e-01 -1.82534113e-01  8.25946212e-04]]
# GSO_coefficients
# [[ 1.          0.          0.          0.        ]
#  [ 0.21259843  1.          0.          0.        ]
#  [-0.69291339 -0.14214553  1.          0.        ]
#  [-0.13385827  1.93435332  0.4583152   1.        ]]
# GSO_vector_norm
# [127.          44.25984252 136.12933642   0.52199801]
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-2  7  7 -5]
#  [ 3 -2  6 -1]
#  [ 2 -8 -9 -7]
#  [ 8 -9  6 -4]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.21259843  1.          0.          0.        ]
#  [-0.69291339 -0.14214553  1.          0.        ]
#  [-0.13385827  1.93435332  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [127.          44.25984252 136.12933642   0.52199801]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[-2  7  7 -5]
#  [ 3 -2  6 -1]
#  [ 2 -8 -9 -7]
#  [ 8 -9  6 -4]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 3 -2  6 -1]
#  [-2  7  7 -5]
#  [ 2 -8 -9 -7]
#  [ 8 -9  6 -4]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.54        1.          0.          0.        ]
#  [-0.5        -0.66269347  1.          0.        ]
#  [ 1.64       -0.54509874  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [-5  9  1 -4]
#  [ 2 -8 -9 -7]
#  [ 8 -9  6 -4]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [-0.5        -0.66269347  1.          0.        ]
#  [ 1.64       -0.54509874  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [ -3   1  -8 -11]
#  [  8  -9   6  -4]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [-0.96        0.33730653  1.          0.        ]
#  [ 1.64       -0.54509874  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]
#  [  8  -9   6  -4]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.04        0.33730653  1.          0.        ]
#  [ 1.64       -0.54509874  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]
#  [  8  -9   6  -4]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.04        0.33730653  1.          0.        ]
#  [ 1.64       -0.54509874  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]
#  [  3   0   7  -8]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.04        0.33730653  1.          0.        ]
#  [ 1.18        0.45490126  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]
#  [  0   2   1  -7]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.04        0.33730653  1.          0.        ]
#  [ 0.18        0.45490126  0.4583152   1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42       136.12933642   0.52199801]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]
#  [  0   2   1  -7]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0   2   1  -7]
#  [  0  -1  -2 -12]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.18        0.45490126  1.          0.        ]
#  [ 0.04        0.33730653  2.14278731  1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42        29.1163494    2.44052718]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0   2   1  -7]
#  [  0  -1  -2 -12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.18        0.45490126  1.          0.        ]
#  [ 0.04        0.33730653  2.14278731  1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42        29.1163494    2.44052718]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0   2   1  -7]
#  [  0  -1  -2 -12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46        1.          0.          0.        ]
#  [ 0.18        0.45490126  1.          0.        ]
#  [ 0.04        0.33730653  2.14278731  1.        ]]
# GSO vector norm : B_star_norm
# [ 50.         112.42        29.1163494    2.44052718]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[  3  -2   6  -1]
#  [ -5   9   1  -4]
#  [  0   2   1  -7]
#  [  0  -1  -2 -12]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  3  -2   6  -1]
#  [  0   2   1  -7]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [-0.46        0.97632684  1.          0.        ]
#  [ 0.04        1.52042764 -0.63745013  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[  3  -2   6  -1]
#  [  0   2   1  -7]
#  [ -5   9   1  -4]
#  [  0  -1  -2 -12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [-0.46        0.97632684  1.          0.        ]
#  [ 0.04        1.52042764 -0.63745013  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  3  -2   6  -1]
#  [  0   2   1  -7]
#  [ -5   7   0   3]
#  [  0  -1  -2 -12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [-0.64       -0.02367316  1.          0.        ]
#  [ 0.04        1.52042764 -0.63745013  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  3  -2   6  -1]
#  [  0   2   1  -7]
#  [ -2   5   6   2]
#  [  0  -1  -2 -12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.36       -0.02367316  1.          0.        ]
#  [ 0.04        1.52042764 -0.63745013  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[  3  -2   6  -1]
#  [  0   2   1  -7]
#  [ -2   5   6   2]
#  [ -2   4   4 -10]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.36       -0.02367316  1.          0.        ]
#  [ 0.4         1.49675449  0.36254987  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]
#  [-2  2  3 -3]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.36       -0.02367316  1.          0.        ]
#  [ 0.22        0.49675449  0.36254987  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]
#  [-2  2  3 -3]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.36       -0.02367316  1.          0.        ]
#  [ 0.22        0.49675449  0.36254987  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       62.49064528  2.44052718]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]
#  [-2  2  3 -3]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  2  3 -3]
#  [-2  5  6  2]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.22        0.49675449  1.          0.        ]
#  [ 0.36       -0.02367316  2.12643349  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       10.65444826 14.31422018]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  2  3 -3]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.22        0.49675449  1.          0.        ]
#  [ 0.36       -0.02367316  2.12643349  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       10.65444826 14.31422018]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  2  3 -3]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.18        1.          0.          0.        ]
#  [ 0.22        0.49675449  1.          0.        ]
#  [ 0.36       -0.02367316  2.12643349  1.        ]]
# GSO vector norm : B_star_norm
# [50.         52.38       10.65444826 14.31422018]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  2  3 -3]
#  [-2  5  6  2]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 3 -2  6 -1]
#  [-2  2  3 -3]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.22        1.          0.          0.        ]
#  [ 0.18        1.10347752  1.          0.        ]
#  [ 0.36        0.93469042 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [50.         23.58       23.66751484 14.31422018]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 3 -2  6 -1]
#  [-2  2  3 -3]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.22        1.          0.          0.        ]
#  [ 0.18        1.10347752  1.          0.        ]
#  [ 0.36        0.93469042 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [50.         23.58       23.66751484 14.31422018]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[ 3 -2  6 -1]
#  [-2  2  3 -3]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-2  2  3 -3]
#  [ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.42307692  1.          0.          0.        ]
#  [ 1.07692308 -0.06276506  1.          0.        ]
#  [ 1.          0.15436811 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [26.         45.34615385 23.66751484 14.31422018]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.42307692  1.          0.          0.        ]
#  [ 1.07692308 -0.06276506  1.          0.        ]
#  [ 1.          0.15436811 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [26.         45.34615385 23.66751484 14.31422018]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 3 -2  6 -1]
#  [ 0  2  1 -7]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.42307692  1.          0.          0.        ]
#  [ 1.07692308 -0.06276506  1.          0.        ]
#  [ 1.          0.15436811 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [26.         45.34615385 23.66751484 14.31422018]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 3 -2  6 -1]
#  [ 2  0 -2 -4]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.42307692  1.          0.          0.        ]
#  [ 0.07692308 -0.06276506  1.          0.        ]
#  [ 1.          0.15436811 -1.07998853  1.        ]]
# GSO vector norm : B_star_norm
# [26.         45.34615385 23.66751484 14.31422018]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[-2  2  3 -3]
#  [ 3 -2  6 -1]
#  [ 2  0 -2 -4]
#  [-2  5  6  2]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [-2  5  6  2]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.         -1.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.         -1.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.         -1.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.         -1.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [-2  5  6  2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.         -1.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [ 0  5  4 -2]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 1.07692308 -0.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [ 2  3  1  1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.42307692 -0.11935484  1.          0.        ]
#  [ 0.07692308 -0.09032258  0.08658257  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 45.00645161 14.31422018]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]
#  [ 2  3  1  1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 2  3  1  1]
#  [ 3 -2  6 -1]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.07692308 -0.09032258  1.          0.        ]
#  [ 0.42307692 -0.11935484  0.26596213  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 14.6516129  43.97005724]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 2  3  1  1]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.07692308 -0.09032258  1.          0.        ]
#  [ 0.42307692 -0.11935484  0.26596213  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 14.6516129  43.97005724]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 2  3  1  1]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.07692308 -0.09032258  1.          0.        ]
#  [ 0.42307692 -0.11935484  0.26596213  1.        ]]
# GSO vector norm : B_star_norm
# [26.         23.84615385 14.6516129  43.97005724]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 2  3  1  1]
#  [ 3 -2  6 -1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-2  2  3 -3]
#  [ 2  3  1  1]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.07692308 -0.14507772  1.          0.        ]
#  [ 0.42307692  0.27979275 -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [26.         14.84615385 23.53367876 43.97005724]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-2  2  3 -3]
#  [ 2  3  1  1]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.07692308  1.          0.          0.        ]
#  [ 0.07692308 -0.14507772  1.          0.        ]
#  [ 0.42307692  0.27979275 -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [26.         14.84615385 23.53367876 43.97005724]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[-2  2  3 -3]
#  [ 2  3  1  1]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.13333333  1.          0.          0.        ]
#  [-0.13333333  0.0880829   1.          0.        ]
#  [ 0.33333333  0.4015544  -0.09533245  1.        ]]
# GSO vector norm : B_star_norm
# [15.         25.73333333 23.53367876 43.97005724]
# ---
# Lovasz condition at k = 3 : True
# k += 1
# [[ 2  3  1  1]
#  [-2  2  3 -3]
#  [ 2  0 -2 -4]
#  [ 3 -2  6 -1]]

# %%
# 標準入力で色々試してみよう
test_LLL_with_stdin()
# Out:
# Enter the dimension of the lattice.
# Enter each basis vector of the lattice
# Enter the value of delta
# ---
# Initial condition :
# GSO_vectors
# [[ 1.00000000e+00  5.00000000e+00  7.00000000e+00  2.30000000e+01]
#  [ 2.33609272e+00  2.86804636e+01  6.35264901e+00 -8.26986755e+00]
#  [-1.30224439e+01  2.84834901e+01 -9.39192893e+01  2.29582617e+01]
#  [-2.52386663e-01  1.13481769e-02  3.77102994e-02 -2.97070945e-03]]
# GSO_coefficients
# [[ 1.          0.          0.          0.        ]
#  [ 3.66390728  1.          0.          0.        ]
#  [ 0.96688742  0.02378179  1.          0.        ]
#  [ 5.0513245   1.07968385 -0.35928898  1.        ]]
# GSO_vector_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-12  34 -87  45]
#  [ 12  46  76  99]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.96688742  0.02378179  1.          0.        ]
#  [ 5.0513245   1.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-12  34 -87  45]
#  [ 12  46  76  99]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.96688742  0.02378179  1.          0.        ]
#  [ 5.0513245   1.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-13  29 -94  22]
#  [ 12  46  76  99]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [-0.03311258  0.02378179  1.          0.        ]
#  [ 5.0513245   1.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-13  29 -94  22]
#  [ 12  46  76  99]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [-0.03311258  0.02378179  1.          0.        ]
#  [ 5.0513245   1.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-13  29 -94  22]
#  [ 10  19  72 115]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [-0.03311258  0.02378179  1.          0.        ]
#  [ 5.38741722  0.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-13  29 -94  22]
#  [  5  -6  37   0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [-0.03311258  0.02378179  1.          0.        ]
#  [ 0.38741722  0.07968385 -0.35928898  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.03288079e+04 6.52587007e-02]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [-13  29 -94  22]
#  [  5  -6  37   0]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [-13  29 -94  22]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [-0.03311258  0.02378179 -2.78313868  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [-13  29 -94  22]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [-0.03311258  0.02378179 -2.78313868  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [-13  29 -94  22]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [-0.03311258  0.02378179 -2.78313868  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [  2  11  17  22]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [ 1.12913907  0.26283335  0.21686132  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [  2  11  17  22]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [ 1.12913907  0.26283335  0.21686132  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [  1   6  10  -1]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.38741722  0.07968385  1.          0.        ]
#  [ 0.12913907  0.26283335  0.21686132  1.        ]]
# GSO vector norm : B_star_norm
# [6.04000000e+02 9.36773179e+02 1.33339631e+03 5.05509561e-01]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]
#  [  1   6  10  -1]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  1   6  10  -1]
#  [  5  -6  37   0]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.12913907  0.26283335  1.          0.        ]
#  [ 0.38741722  0.07968385  4.57436656  1.        ]]
# GSO vector norm : B_star_norm
# [604.         936.77317881  63.21357839  10.66297151]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  1   6  10  -1]
#  [  5  -6  37   0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.12913907  0.26283335  1.          0.        ]
#  [ 0.38741722  0.07968385  4.57436656  1.        ]]
# GSO vector norm : B_star_norm
# [604.         936.77317881  63.21357839  10.66297151]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  1   6  10  -1]
#  [  5  -6  37   0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.33609272  1.          0.          0.        ]
#  [ 0.12913907  0.26283335  1.          0.        ]
#  [ 0.38741722  0.07968385  4.57436656  1.        ]]
# GSO vector norm : B_star_norm
# [604.         936.77317881  63.21357839  10.66297151]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[  1   5   7  23]
#  [  2  27   4 -16]
#  [  1   6  10  -1]
#  [  5  -6  37   0]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  1   5   7  23]
#  [  1   6  10  -1]
#  [  2  27   4 -16]
#  [  5  -6  37   0]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.12913907  1.          0.          0.        ]
#  [-0.33609272  1.92465186  1.          0.        ]
#  [ 0.38741722  2.41372884 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [604.         127.92715232 462.89457473  10.66297151]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[  1   5   7  23]
#  [  1   6  10  -1]
#  [  2  27   4 -16]
#  [  5  -6  37   0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.12913907  1.          0.          0.        ]
#  [-0.33609272  1.92465186  1.          0.        ]
#  [ 0.38741722  2.41372884 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [604.         127.92715232 462.89457473  10.66297151]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[  1   5   7  23]
#  [  1   6  10  -1]
#  [  2  27   4 -16]
#  [  5  -6  37   0]]
# ---
# swap(B[k-1], B[k])
# ---
# [[  1   6  10  -1]
#  [  1   5   7  23]
#  [  2  27   4 -16]
#  [  5  -6  37   0]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.56521739  1.          0.          0.        ]
#  [ 1.5942029  -0.58464047  1.          0.        ]
#  [ 2.45652174  0.07571051 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[  1   6  10  -1]
#  [  0  -1  -3  24]
#  [  2  27   4 -16]
#  [  5  -6  37   0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 1.5942029  -0.58464047  1.          0.        ]
#  [ 2.45652174  0.07571051 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 2 26  1  8]
#  [ 5 -6 37  0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 1.15942029  0.41535953  1.          0.        ]
#  [ 2.45652174  0.07571051 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]
#  [ 5 -6 37  0]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 0.15942029  0.41535953  1.          0.        ]
#  [ 2.45652174  0.07571051 -1.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]
#  [ 6 14 28  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 0.15942029  0.41535953  1.          0.        ]
#  [ 2.61594203  0.49107004 -0.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]
#  [ 6 14 28  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 0.15942029  0.41535953  1.          0.        ]
#  [ 2.61594203  0.49107004 -0.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]
#  [ 3 -4 -2 12]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [ 0.15942029  0.41535953  1.          0.        ]
#  [-0.38405797  0.49107004 -0.12261223  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348 462.89457473  10.66297151]
# ---
# Lovasz condition at k = 3 : False
# ---
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]
#  [ 3 -4 -2 12]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [-0.38405797  0.49107004  1.          0.        ]
#  [ 0.15942029  0.41535953 -3.22077411  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348  17.62201688 280.09459408]
# ---
# update k = max(k-1,1) = 2
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [-0.38405797  0.49107004  1.          0.        ]
#  [ 0.15942029  0.41535953 -3.22077411  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348  17.62201688 280.09459408]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.43478261  1.          0.          0.        ]
#  [-0.38405797  0.49107004  1.          0.        ]
#  [ 0.15942029  0.41535953 -3.22077411  1.        ]]
# GSO vector norm : B_star_norm
# [138.         559.91304348  17.62201688 280.09459408]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[ 1  6 10 -1]
#  [ 0 -1 -3 24]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.38405797  1.          0.          0.        ]
#  [-0.43478261  1.80128175  1.          0.        ]
#  [ 0.15942029  0.37635889  1.9969852   1.        ]]
# GSO vector norm : B_star_norm
# [138.         152.64492754  64.63887966 280.09459408]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [ 0 -1 -3 24]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.38405797  1.          0.          0.        ]
#  [-0.43478261  1.80128175  1.          0.        ]
#  [ 0.15942029  0.37635889  1.9969852   1.        ]]
# GSO vector norm : B_star_norm
# [138.         152.64492754  64.63887966 280.09459408]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [-6  7  1  0]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.38405797  1.          0.          0.        ]
#  [ 0.33333333 -0.19871825  1.          0.        ]
#  [ 0.15942029  0.37635889  1.9969852   1.        ]]
# GSO vector norm : B_star_norm
# [138.         152.64492754  64.63887966 280.09459408]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [-6  7  1  0]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.38405797  1.          0.          0.        ]
#  [ 0.33333333 -0.19871825  1.          0.        ]
#  [ 0.15942029  0.37635889  1.9969852   1.        ]]
# GSO vector norm : B_star_norm
# [138.         152.64492754  64.63887966 280.09459408]
# ---
# Lovasz condition at k = 2 : False
# ---
# [[ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [-6  7  1  0]
#  [ 1 20 -9  9]]
# ---
# swap(B[k-1], B[k])
# ---
# [[ 1  6 10 -1]
#  [-6  7  1  0]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.33333333  1.          0.          0.        ]
#  [-0.38405797 -0.42924528  1.          0.        ]
#  [ 0.15942029  1.66509434  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [138.          70.66666667 139.62448728 280.09459408]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[ 1  6 10 -1]
#  [-6  7  1  0]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.33333333  1.          0.          0.        ]
#  [-0.38405797 -0.42924528  1.          0.        ]
#  [ 0.15942029  1.66509434  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [138.          70.66666667 139.62448728 280.09459408]
# ---
# Lovasz condition at k = 1 : False
# ---
# [[ 1  6 10 -1]
#  [-6  7  1  0]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# ---
# swap(B[k-1], B[k])
# ---
# [[-6  7  1  0]
#  [ 1  6 10 -1]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# ---
# update GSO info
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [ 0.53488372  1.          0.          0.        ]
#  [-0.55813953 -0.24097621  1.          0.        ]
#  [ 1.45348837 -0.39561116  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# update k = max(k-1,1) = 1
# ---
# k = 1
# ---
# Partial_Size_Reduction
# (k,j) :
# 1 0
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [-0.55813953 -0.24097621  1.          0.        ]
#  [ 1.45348837 -0.39561116  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Lovasz condition at k = 1 : True
# k += 1
# ---
# k = 2
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 1
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [ 3 -4 -2 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [-0.55813953 -0.24097621  1.          0.        ]
#  [ 1.45348837 -0.39561116  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Partial_Size_Reduction
# (k,j) :
# 2 0
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [-3  3 -1 12]
#  [ 1 20 -9  9]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [ 0.44186047 -0.24097621  1.          0.        ]
#  [ 1.45348837 -0.39561116  0.7731963   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Lovasz condition at k = 2 : True
# k += 1
# ---
# k = 3
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 2
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [-3  3 -1 12]
#  [ 4 17 -8 -3]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [ 0.44186047 -0.24097621  1.          0.        ]
#  [ 1.01162791 -0.15463495 -0.2268037   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 1
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [-3  3 -1 12]
#  [ 4 17 -8 -3]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [ 0.44186047 -0.24097621  1.          0.        ]
#  [ 1.01162791 -0.15463495 -0.2268037   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Partial_Size_Reduction
# (k,j) :
# 3 0
# Basis matrix : B
# [[-6  7  1  0]
#  [ 7 -1  9 -1]
#  [-3  3 -1 12]
#  [10 10 -9 -3]]
# GSO coefficients : mu
# [[ 1.          0.          0.          0.        ]
#  [-0.46511628  1.          0.          0.        ]
#  [ 0.44186047 -0.24097621  1.          0.        ]
#  [ 0.01162791 -0.15463495 -0.2268037   1.        ]]
# GSO vector norm : B_star_norm
# [ 86.         113.39534884 139.62448728 280.09459408]
# ---
# Lovasz condition at k = 3 : True
# k += 1

# %% [markdown]
# ランダムなフルランク行列に対するLLL

# %%
test_LLL_with_random_matrix()
# Out:
# Enter the size of matrix
# The basis matrix is
# [[-477 -991  481 ...  754  672  191]
#  [  33   51  507 ...  935 -584  526]
#  [ 530  721  883 ...  622  738  186]
#  ...
#  [ 636  506  422 ...   67 -433  840]
#  [ 319  923  512 ...  783  429  447]
#  [  65 -286 -831 ... -849 -187 -866]]
# ---
# Enter the value of delta
# ---
# Do you want to check each step?[y/n]
# the LLL reduced basis is
# [[ -590   305  -362 ...   517   821  -166]
#  [ -591  -424  -107 ...   970   278  -393]
#  [ -577   889    50 ...  -395  -462  -648]
#  ...
#  [  461 -1013   -39 ...  2799  1714   632]
#  [  993 -2770   423 ... -1298  -859   824]
#  [  -80   396   610 ...   301   224  -476]]
